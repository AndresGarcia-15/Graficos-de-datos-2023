# %%
# Let's load in agian the libraries we need
# These are same ones has we have used in all other sessions
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
#We are going to use our air passenger dataset, so upload this to COLAB,
# then load into pandas
# The file is available at the following link

ruta_completa = 'output2_2023_eit195.csv'

data = pd.read_csv(ruta_completa)

# Quickly check the data looks like we expect
print(data.head())
# Out:
#    Unnamed: 0                 date  \
# 0           0  2023-01-01 01:13:00
# 1           1  2023-01-01 13:13:00
# 2           2  2023-01-02 01:13:00
# 3           3  2023-01-02 13:13:00
# 4           4  2023-01-03 01:13:00
#
#                                                  url   entropy  \
# 0  https://soho.nascom.nasa.gov/data/REPROCESSING...  5.895714
# 1  https://soho.nascom.nasa.gov/data/REPROCESSING...  5.871364
# 2  https://soho.nascom.nasa.gov/data/REPROCESSING...  5.786832
# 3  https://soho.nascom.nasa.gov/data/REPROCESSING...  5.794061
# 4  https://soho.nascom.nasa.gov/data/REPROCESSING...  5.804059
#
#    mean_intensity  standard_deviation  skewness  kurtosis  \
# 0       44.272131           44.962445  1.270519  5.224143
# 1       44.154725           44.643901  1.226184  5.119539
# 2       43.857519           44.000848  1.098195  4.641994
# 3       43.692347           43.499303  1.072080  4.576271
# 4       44.195916           43.728649  1.015556  4.351632
#
#    relative_smoothness  uniformity  fractal_dimension  taruma_contrast  \
# 0             0.999506    0.090129           1.318321      1337.199093
# 1             0.999499    0.092855           1.311236      1325.002072
# 2             0.999484    0.100449           1.316191      1319.003547
# 3             0.999472    0.099077           1.312849      1293.709242
# 4             0.999477    0.098871           1.313847      1323.942326
#
#    taruma_directionality  taruma_coarseness  taruma_linelikeness  \
# 0               0.988223          26.241735             1.326636
# 1               0.988499          26.238060             1.317845
# 2               0.989182          26.126994             1.296719
# 3               0.989083          26.261290             1.299602
# 4               0.989065          26.272098             1.301461
#
#    taruma_regularity  taruma_roughness
# 0          30.668852          0.325504
# 1          30.233240          0.324681
# 2          30.479163          0.324773
# 3          30.056931          0.323902
# 4          30.293776          0.324170

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado "data" y la columna "date" contiene las fechas

# Intenta convertir la columna "date" a tipo de dato datetime especificando los formatos posibles
data['DateFormatted'] = pd.to_datetime(data['date'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
data['DateFormatted'].fillna(pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce'), inplace=True)

# Establece la columna "DateFormatted" como el índice de tiempo
data.set_index('DateFormatted', inplace=True)

# Ahora "DateFormatted" se convierte en el índice de tiempo con fechas válidas

# %%
data.head()
# Out:
#                      Unnamed: 0                 date  \
# DateFormatted
# 2023-01-01 01:13:00           0  2023-01-01 01:13:00
# 2023-01-01 13:13:00           1  2023-01-01 13:13:00
# 2023-01-02 01:13:00           2  2023-01-02 01:13:00
# 2023-01-02 13:13:00           3  2023-01-02 13:13:00
# 2023-01-03 01:13:00           4  2023-01-03 01:13:00
#
#                                                                    url  \
# DateFormatted
# 2023-01-01 01:13:00  https://soho.nascom.nasa.gov/data/REPROCESSING...
# 2023-01-01 13:13:00  https://soho.nascom.nasa.gov/data/REPROCESSING...
# 2023-01-02 01:13:00  https://soho.nascom.nasa.gov/data/REPROCESSING...
# 2023-01-02 13:13:00  https://soho.nascom.nasa.gov/data/REPROCESSING...
# 2023-01-03 01:13:00  https://soho.nascom.nasa.gov/data/REPROCESSING...
#
#                       entropy  mean_intensity  standard_deviation  skewness  \
# DateFormatted
# 2023-01-01 01:13:00  5.895714       44.272131           44.962445  1.270519
# 2023-01-01 13:13:00  5.871364       44.154725           44.643901  1.226184
# 2023-01-02 01:13:00  5.786832       43.857519           44.000848  1.098195
# 2023-01-02 13:13:00  5.794061       43.692347           43.499303  1.072080
# 2023-01-03 01:13:00  5.804059       44.195916           43.728649  1.015556
#
#                      kurtosis  relative_smoothness  uniformity  \
# DateFormatted
# 2023-01-01 01:13:00  5.224143             0.999506    0.090129
# 2023-01-01 13:13:00  5.119539             0.999499    0.092855
# 2023-01-02 01:13:00  4.641994             0.999484    0.100449
# 2023-01-02 13:13:00  4.576271             0.999472    0.099077
# 2023-01-03 01:13:00  4.351632             0.999477    0.098871
#
#                      fractal_dimension  taruma_contrast  \
# DateFormatted
# 2023-01-01 01:13:00           1.318321      1337.199093
# 2023-01-01 13:13:00           1.311236      1325.002072
# 2023-01-02 01:13:00           1.316191      1319.003547
# 2023-01-02 13:13:00           1.312849      1293.709242
# 2023-01-03 01:13:00           1.313847      1323.942326
#
#                      taruma_directionality  taruma_coarseness  \
# DateFormatted
# 2023-01-01 01:13:00               0.988223          26.241735
# 2023-01-01 13:13:00               0.988499          26.238060
# 2023-01-02 01:13:00               0.989182          26.126994
# 2023-01-02 13:13:00               0.989083          26.261290
# 2023-01-03 01:13:00               0.989065          26.272098
#
#                      taruma_linelikeness  taruma_regularity  taruma_roughness
# DateFormatted
# 2023-01-01 01:13:00             1.326636          30.668852          0.325504
# 2023-01-01 13:13:00             1.317845          30.233240          0.324681
# 2023-01-02 01:13:00             1.296719          30.479163          0.324773
# 2023-01-02 13:13:00             1.299602          30.056931          0.323902
# 2023-01-03 01:13:00             1.301461          30.293776          0.324170

# %%
# Plot it
data["fractal_dimension"].plot()
# Out:
# <Axes: xlabel='DateFormatted'>

# %%
# plot it 
data["entropy"].plot()
# Out:
# <Axes: xlabel='DateFormatted'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# We can use the seaborn package to make some better quality plots
# Let's plot the entropy and fractal dimension together
# We can do this using the following command
# We can also add a title and change the size of the plot

##plt.figure(figsize=(12, 6))

###plt.title("Entropy and Fractal Dimension")
###sns.lineplot(data=data[['entropy', 'fractal_dimension']])
###plt.show()


plt.figure(figsize=(12, 12))  


plt.subplot(4, 4, 1)
plt.plot(data['entropy'])
plt.title('Entropy')

plt.subplot(4, 4, 2)
plt.plot(data['fractal_dimension'])
plt.title('Fractal Dimension')

plt.subplot(4, 4, 3)
plt.plot(data['mean_intensity'])
plt.title('Mean Intensity')

plt.subplot(4, 4, 4)
plt.plot(data['standard_deviation'])
plt.title('Standard Deviation')

plt.subplot(4, 4, 5)
plt.plot(data['uniformity'])
plt.title('Uniformity')

plt.subplot(4, 4, 6)
plt.plot(data['skewness'])
plt.title('Skewness')

plt.subplot(4, 4, 7)
plt.plot(data['kurtosis'])
plt.title('Kurtosis')

plt.subplot(4, 4, 8)
plt.plot(data['relative_smoothness'])
plt.title('Relative Smoothness')

plt.subplot(4, 4, 9)
plt.plot(data['taruma_contrast'])
plt.title('Taruma Contrast')

plt.subplot(4, 4, 10)
plt.plot(data['taruma_directionality'])
plt.title('Taruma Directionality')

plt.subplot(4, 4, 11)
plt.plot(data['taruma_coarseness'])
plt.title('Taruma Coarseness')

plt.subplot(4, 4, 12)
plt.plot(data['taruma_linelikeness'])
plt.title('Taruma Linelikeness')

plt.subplot(4, 4, 13)
plt.plot(data['taruma_roughness'])
plt.title('Taruma Roughness')

plt.subplot(4, 4, 14)
plt.plot(data['taruma_regularity'])
plt.title('Taruma Regularity')

plt.tight_layout()


plt.show()
