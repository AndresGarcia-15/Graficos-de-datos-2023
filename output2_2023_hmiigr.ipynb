# %%
# Let's load in agian the libraries we need
# These are same ones has we have used in all other sessions
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
#We are going to use our air passenger dataset, so upload this to COLAB,
# then load into pandas
# The file is available at the following link
ruta_completa = 'output2_2023_hmiigr.csv'

data = pd.read_csv(ruta_completa)

# Quickly check the data looks like we expect
print(data.head())
# Out:
#    Unnamed: 0                 date  \
# 0           0  2023-01-01 00:00:00
# 1           1  2023-01-01 01:30:00
# 2           2  2023-01-01 03:00:00
# 3           3  2023-01-01 04:30:00
# 4           4  2023-01-01 06:00:00
#
#                                                  url   entropy  \
# 0  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.358187
# 1  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.361888
# 2  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.357202
# 3  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.354284
# 4  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.346628
#
#    mean_intensity  standard_deviation  skewness  kurtosis  \
# 0      121.205601           79.538166 -0.851964  1.756590
# 1      121.177648           79.551488 -0.851036  1.755153
# 2      121.155685           79.559954 -0.850501  1.754113
# 3      121.133716           79.567305 -0.849934  1.753048
# 4      121.114936           79.571520 -0.849647  1.752170
#
#    relative_smoothness  uniformity  fractal_dimension  taruma_contrast  \
# 0             0.999842    0.099298           1.355936      5495.200645
# 1             0.999842    0.099368           1.355530      5498.166331
# 2             0.999842    0.099539           1.356578      5500.151486
# 3             0.999842    0.099550           1.358343      5502.003294
# 4             0.999842    0.099885           1.353985      5503.275265
#
#    taruma_directionality  taruma_coarseness  taruma_linelikeness  \
# 0               0.986984          23.993891             1.378372
# 1               0.986948          24.005157             1.376887
# 2               0.986977          23.992121             1.377051
# 3               0.987007          23.986551             1.376771
# 4               0.987005          23.977690             1.375726
#
#    taruma_regularity  taruma_roughness
# 0          78.481602          0.303016
# 1          77.828755          0.302980
# 2          78.166450          0.302999
# 3          77.896977          0.302874
# 4          78.450874          0.302986

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado "data" y la columna "date" contiene las fechas

# Intenta convertir la columna "date" a tipo de dato datetime especificando los formatos posibles
data['DateFormatted'] = pd.to_datetime(data['date'], format='%d/%m/%Y %H:%M:%S', errors='coerce')
data['DateFormatted'].fillna(pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce'), inplace=True)

# Establece la columna "DateFormatted" como el índice de tiempo
data.set_index('DateFormatted', inplace=True)

# Ahora "DateFormatted" se convierte en el índice de tiempo con fechas válidas

# %%
data.head()
# Out:
#    Unnamed: 0                 date  \
# 0           0  2023-01-01 00:00:00
# 1           1  2023-01-01 01:30:00
# 2           2  2023-01-01 03:00:00
# 3           3  2023-01-01 04:30:00
# 4           4  2023-01-01 06:00:00
#
#                                                  url   entropy  \
# 0  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.358187
# 1  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.361888
# 2  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.357202
# 3  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.354284
# 4  https://soho.nascom.nasa.gov/data/REPROCESSING...  4.346628
#
#    mean_intensity  standard_deviation  skewness  kurtosis  \
# 0      121.205601           79.538166 -0.851964  1.756590
# 1      121.177648           79.551488 -0.851036  1.755153
# 2      121.155685           79.559954 -0.850501  1.754113
# 3      121.133716           79.567305 -0.849934  1.753048
# 4      121.114936           79.571520 -0.849647  1.752170
#
#    relative_smoothness  uniformity  fractal_dimension  taruma_contrast  \
# 0             0.999842    0.099298           1.355936      5495.200645
# 1             0.999842    0.099368           1.355530      5498.166331
# 2             0.999842    0.099539           1.356578      5500.151486
# 3             0.999842    0.099550           1.358343      5502.003294
# 4             0.999842    0.099885           1.353985      5503.275265
#
#    taruma_directionality  taruma_coarseness  taruma_linelikeness  \
# 0               0.986984          23.993891             1.378372
# 1               0.986948          24.005157             1.376887
# 2               0.986977          23.992121             1.377051
# 3               0.987007          23.986551             1.376771
# 4               0.987005          23.977690             1.375726
#
#    taruma_regularity  taruma_roughness
# 0          78.481602          0.303016
# 1          77.828755          0.302980
# 2          78.166450          0.302999
# 3          77.896977          0.302874
# 4          78.450874          0.302986

# %%
# Plot it
data["fractal_dimension"].plot()
# Out:
# <Axes: xlabel='DateFormatted'>

# %%
data["entropy"].plot(figsize=(15, 6))
# Out:
# <Axes: xlabel='DateFormatted'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# We can use the seaborn package to make some better quality plots
# Let's plot the entropy and fractal dimension together
# We can do this using the following command
# We can also add a title and change the size of the plot

##plt.figure(figsize=(12, 6))

###plt.title("Entropy and Fractal Dimension")
###sns.lineplot(data=data[['entropy', 'fractal_dimension']])
###plt.show()


plt.figure(figsize=(15, 15))  


plt.subplot(4, 4, 1)
plt.plot(data['entropy'])
plt.title('Entropy')

plt.subplot(4, 4, 2)
plt.plot(data['fractal_dimension'])
plt.title('Fractal Dimension')

plt.subplot(4, 4, 3)
plt.plot(data['mean_intensity'])
plt.title('Mean Intensity')

plt.subplot(4, 4, 4)
plt.plot(data['standard_deviation'])
plt.title('Standard Deviation')

plt.subplot(4, 4, 5)
plt.plot(data['uniformity'])
plt.title('Uniformity')

plt.subplot(4, 4, 6)
plt.plot(data['skewness'])
plt.title('Skewness')

plt.subplot(4, 4, 7)
plt.plot(data['kurtosis'])
plt.title('Kurtosis')

plt.subplot(4, 4, 8)
plt.plot(data['relative_smoothness'])
plt.title('Relative Smoothness')

plt.subplot(4, 4, 9)
plt.plot(data['taruma_contrast'])
plt.title('Taruma Contrast')

plt.subplot(4, 4, 10)
plt.plot(data['taruma_directionality'])
plt.title('Taruma Directionality')

plt.subplot(4, 4, 11)
plt.plot(data['taruma_coarseness'])
plt.title('Taruma Coarseness')

plt.subplot(4, 4, 12)
plt.plot(data['taruma_linelikeness'])
plt.title('Taruma Linelikeness')

plt.subplot(4, 4, 13)
plt.plot(data['taruma_roughness'])
plt.title('Taruma Roughness')

plt.subplot(4, 4, 14)
plt.plot(data['taruma_regularity'])
plt.title('Taruma Regularity')

plt.tight_layout()


plt.show()
